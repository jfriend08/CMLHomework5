# %% [markdown]
# # Section 3
# ----------------------------------------

# %% [markdown]
# ## Online mini-batch k-means
# - load actual music data and select genre of interest for binary classification
# - perform feature extration and normalization
# - perform mini-batch k-means for finding centroids
# - we should never use the data for twice, and here I split the 10%/90% for total data as testing/training set , and then split 20%/80% of the training data for finding centers and training classifier purpose

# %%
# %matplotlib nbagg

import numpy as np
import random, sys
import points as pt
import librosa
import cPickle as pickle
import myMiniBatchKmeans as miniK
from sklearn import preprocessing
from sklearn.cross_validation import train_test_split
from  scipy.spatial.distance import euclidean
from librosa.util import normalize
from pylab import plt


X, y = miniK.getData("../homework2/data/data_small8.in")
X_new, y_new = miniK.selectGenre(X, y, 0) #binary

rng = np.random.RandomState(19850920)
permutation = rng.permutation(len(X_new))
X_new, y_new = X_new[permutation], y_new[permutation]
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size=0.10, random_state=2010)
X_train_center, X_train_classifier, y_train_center, y_train_classifier = train_test_split(X_train, y_train, test_size=0.8, random_state=2010)

X_train_center_features = miniK.featureExtraction(X_train_center) #includes MFCC and normalization
X_train_classifier_features = miniK.featureExtraction(X_train_classifier) #includes MFCC and normalization
print "X_train_center_features.shape", X_train_center_features.shape


mbk = miniK.miniBatchKmeans(8, max_iter=100, batch_size=10000)
mbk.fix(X_train_center_features)
distortion, centroids = mbk.getBestCentroids() #get the best centroid over each iteration

print "distortion", distortion, "centroids.shape", centroids.shape
print centroids
# Out:
# X size/number of songs: 80
# Number of clips per song: 10
# y size: 80
# After MFCC X.shape (2, 10, 12, 129)
# X_train_flattened.shape (20, 12, 129)
# After transpose X_train_flattened.shape (20, 129, 12)
# After MFCC X.shape (12, 10, 12, 129)
# X_train_flattened.shape (120, 12, 129)
# After transpose X_train_flattened.shape (120, 129, 12)
# X_train_center_features.shape (2580, 12)
# n_iter is 100
# round: 0 squared_diff 0.687536415425 noImproveCount 0 improvement 0
# round: 1 squared_diff 0.0479565581679 noImproveCount 0 improvement 0.93024870088
# round: 2 squared_diff 0.00426047356056 noImproveCount 0 improvement 0.91115973032
# round: 3 squared_diff 0.0016299843566 noImproveCount 0 improvement 0.617417093796
# round: 4 squared_diff 0.00079758831417 noImproveCount 0 improvement 0.510677319731
# round: 5 squared_diff 0.000559641995473 noImproveCount 0 improvement 0.298332252955
# round: 6 squared_diff 0.000254566547281 noImproveCount 0 improvement 0.545126081781
# round: 7 squared_diff 0.00019786001097 noImproveCount 0 improvement 0.222757219739
# round: 8 squared_diff 0.000240207954228 noImproveCount 0 improvement 0.214029823664
# round: 9 squared_diff 0.000161659123446 noImproveCount 0 improvement 0.327003454298
# round: 10 squared_diff 0.000104916033651 noImproveCount 0 improvement 0.351004561852
# round: 11 squared_diff 9.55230727194e-05 noImproveCount 0 improvement 0.0895283647773
# round: 12 squared_diff 7.11294334892e-05 noImproveCount 0 improvement 0.255369080326
# round: 13 squared_diff 7.52698268799e-05 noImproveCount 0 improvement 0.0582092839444
# round: 14 squared_diff 6.32434769082e-05 noImproveCount 0 improvement 0.159776506341
# round: 15 squared_diff 4.6563006608e-05 noImproveCount 0 improvement 0.263750051637
# round: 16 squared_diff 4.14534993665e-05 noImproveCount 0 improvement 0.109733189792
# round: 17 squared_diff 3.51017905255e-05 noImproveCount 0 improvement 0.15322491317
# round: 18 squared_diff 2.84986968389e-05 noImproveCount 0 improvement 0.188112731224
# round: 19 squared_diff 2.72333923578e-05 noImproveCount 0 improvement 0.0443986785865
# round: 20 squared_diff 2.28851030186e-05 noImproveCount 0 improvement 0.159667561134
# round: 21 squared_diff 2.03241532833e-05 noImproveCount 0 improvement 0.111904662753
# round: 22 squared_diff 1.5454773864e-05 noImproveCount 0 improvement 0.239585844063
# round: 23 squared_diff 1.3019973683e-05 noImproveCount 0 improvement 0.157543565662
# round: 24 squared_diff 1.35834776564e-05 noImproveCount 0 improvement 0.0432799625474
# round: 25 squared_diff 1.47990370911e-05 noImproveCount 0 improvement 0.0894880873307
# round: 26 squared_diff 1.35802717627e-05 noImproveCount 0 improvement 0.0823543667679
# round: 27 squared_diff 7.83730418574e-06 noImproveCount 0 improvement 0.422890475045
# round: 28 squared_diff 9.25071117093e-06 noImproveCount 0 improvement 0.180343515026
# round: 29 squared_diff 7.79211496796e-06 noImproveCount 0 improvement 0.157673953497
# round: 30 squared_diff 6.3199147203e-06 noImproveCount 0 improvement 0.188934615788
# round: 31 squared_diff 6.94671634353e-06 noImproveCount 0 improvement 0.0991788103101
# round: 32 squared_diff 6.71079470577e-06 noImproveCount 0 improvement 0.0339616051795
# round: 33 squared_diff 6.53350282348e-06 noImproveCount 0 improvement 0.0264189101392
# round: 34 squared_diff 5.15814124658e-06 noImproveCount 0 improvement 0.210509065972
# round: 35 squared_diff 4.78460079903e-06 noImproveCount 0 improvement 0.0724176461425
# round: 36 squared_diff 4.55296887612e-06 noImproveCount 0 improvement 0.0484119642659
# round: 37 squared_diff 3.92101234996e-06 noImproveCount 0 improvement 0.13880097654
# round: 38 squared_diff 3.84311299187e-06 noImproveCount 0 improvement 0.0198671544846
# round: 39 squared_diff 3.63762074561e-06 noImproveCount 0 improvement 0.053470258796
# round: 40 squared_diff 3.45230032133e-06 noImproveCount 0 improvement 0.0509455045585
# round: 41 squared_diff 3.08518228228e-06 noImproveCount 0 improvement 0.106340122494
# round: 42 squared_diff 2.76998258702e-06 noImproveCount 0 improvement 0.102165663621
# round: 43 squared_diff 3.06396184812e-06 noImproveCount 0 improvement 0.106130364312
# round: 44 squared_diff 2.36547816098e-06 noImproveCount 0 improvement 0.227967488422
# round: 45 squared_diff 2.82857541597e-06 noImproveCount 0 improvement 0.195773210943
# round: 46 squared_diff 2.12289775058e-06 noImproveCount 0 improvement 0.249481651223
# round: 47 squared_diff 2.58612831513e-06 noImproveCount 0 improvement 0.218206724474
# round: 48 squared_diff 2.53712293452e-06 noImproveCount 0 improvement 0.0189493229408
# round: 49 squared_diff 2.69647324267e-06 noImproveCount 0 improvement 0.0628074840143
# round: 50 squared_diff 2.12622893312e-06 noImproveCount 0 improvement 0.211477829829
# round: 51 squared_diff 1.53939245856e-06 noImproveCount 0 improvement 0.27599872498
# round: 52 squared_diff 1.74589415919e-06 noImproveCount 0 improvement 0.134144934564
# round: 53 squared_diff 1.64905196188e-06 noImproveCount 0 improvement 0.0554685384529
# round: 54 squared_diff 1.84702721971e-06 noImproveCount 0 improvement 0.120053983987
# round: 55 squared_diff 1.16824468186e-06 noImproveCount 0 improvement 0.367500018739
# round: 56 squared_diff 1.12665435651e-06 noImproveCount 0 improvement 0.03560069735
# round: 57 squared_diff 1.05497003791e-06 noImproveCount 0 improvement 0.0636258300371
# round: 58 squared_diff 1.10058577511e-06 noImproveCount 0 improvement 0.0432388935853
# round: 59 squared_diff 1.47838609224e-06 noImproveCount 0 improvement 0.343272033561
# round: 60 squared_diff 1.26437532573e-06 noImproveCount 0 improvement 0.144759726593
# round: 61 squared_diff 1.24878196063e-06 noImproveCount 0 improvement 0.0123328609691
# round: 62 squared_diff 1.22260575616e-06 noImproveCount 0 improvement 0.020961389008
# round: 63 squared_diff 1.07261659361e-06 noImproveCount 0 improvement 0.122679908714
# round: 64 squared_diff 9.45508499351e-07 noImproveCount 0 improvement 0.118502822921
# round: 65 squared_diff 9.2543572395e-07 noImproveCount 0 improvement 0.0212296086334
# round: 66 squared_diff 7.37058260297e-07 noImproveCount 0 improvement 0.20355542668
# round: 67 squared_diff 9.08512788007e-07 noImproveCount 0 improvement 0.232620047758
# round: 68 squared_diff 1.11711552711e-06 noImproveCount 0 improvement 0.229609029016
# round: 69 squared_diff 9.14680294612e-07 noImproveCount 0 improvement 0.181212441852
# round: 70 squared_diff 6.48975016212e-07 noImproveCount 0 improvement 0.290489780926
# round: 71 squared_diff 7.4252119433e-07 noImproveCount 0 improvement 0.144144498294
# round: 72 squared_diff 7.50578778683e-07 noImproveCount 0 improvement 0.0108516557029
# round: 73 squared_diff 7.24749404138e-07 noImproveCount 0 improvement 0.03441260968
# round: 74 squared_diff 5.51510070001e-07 noImproveCount 0 improvement 0.239033427482
# round: 75 squared_diff 5.85657385126e-07 noImproveCount 0 improvement 0.0619160319684
# round: 76 squared_diff 5.90163541997e-07 noImproveCount 0 improvement 0.00769418603012
# round: 77 squared_diff 6.03628654479e-07 noImproveCount 0 improvement 0.0228159002096
# round: 78 squared_diff 5.10292013702e-07 noImproveCount 0 improvement 0.154625927852
# round: 79 squared_diff 4.7388828421e-07 noImproveCount 0 improvement 0.0713390147491
# round: 80 squared_diff 4.71503182987e-07 noImproveCount 0 improvement 0.00503304534431
# round: 81 squared_diff 5.71645607574e-07 noImproveCount 0 improvement 0.212389710611
# round: 82 squared_diff 5.25215397904e-07 noImproveCount 0 improvement 0.0812220177245
# round: 83 squared_diff 5.35728302964e-07 noImproveCount 0 improvement 0.0200163687178
# round: 84 squared_diff 5.34480593316e-07 noImproveCount 0 improvement 0.00232899707141
# round: 85 squared_diff 5.6473665379e-07 noImproveCount 0 improvement 0.0566083424783
# round: 86 squared_diff 5.0334741401e-07 noImproveCount 0 improvement 0.108704188701
# round: 87 squared_diff 4.08528188213e-07 noImproveCount 0 improvement 0.18837729798
# round: 88 squared_diff 4.94340852603e-07 noImproveCount 0 improvement 0.21005322733
# round: 89 squared_diff 3.87420984816e-07 noImproveCount 0 improvement 0.216287744021
# round: 90 squared_diff 3.88009440569e-07 noImproveCount 0 improvement 0.00151890521309
# round: 91 squared_diff 4.79315331464e-07 noImproveCount 0 improvement 0.235318735443
# round: 92 squared_diff 4.5725957819e-07 noImproveCount 0 improvement 0.0460151216247
# round: 93 squared_diff 4.17407169575e-07 noImproveCount 0 improvement 0.0871548908236
# round: 94 squared_diff 4.682280824e-07 noImproveCount 0 improvement 0.121753809062
# round: 95 squared_diff 3.69323597154e-07 noImproveCount 0 improvement 0.211231425376
# round: 96 squared_diff 3.1862738871e-07 noImproveCount 0 improvement 0.137267720867
# round: 97 squared_diff 3.89932349585e-07 noImproveCount 0 improvement 0.223787920942
# round: 98 squared_diff 3.30061864643e-07 noImproveCount 0 improvement 0.153540697524
# round: 99 squared_diff 3.28129855826e-07 noImproveCount 0 improvement 0.00585347482813
# distortion 2.69745103823e-07 centroids.shape (8, 12)
# [[ 0.19711772  0.25952    -0.12952947  0.21714726  0.00894286  0.08371785
#   -0.08032873  0.02365394 -0.02572696  0.06109322 -0.0220181  -0.00224753]
#  [ 0.20201297  0.22091114 -0.4586191   0.13614498 -0.35178668  0.0694944
#   -0.0578302  -0.15257753 -0.18052512 -0.04620111 -0.09522905 -0.23142834]
#  [ 0.22310504  0.24161178 -0.18027082  0.2357276  -0.11461345  0.19590901
#   -0.12579849  0.19934763 -0.10083274  0.15901312 -0.20273926  0.05279676]
#  [ 0.23496236  0.22233091 -0.0838213   0.13885762 -0.26096664  0.23683896
#    0.28246517  0.24559414 -0.30684818  0.30379417 -0.03743268  0.15039274]
#  [ 0.23960819  0.20517054 -0.2003999   0.22161218 -0.15852195  0.19501671
#   -0.20219305  0.21679641 -0.16397133  0.27841206 -0.03029809  0.31528103]
#  [ 0.23239287  0.17376064 -0.03160216  0.20486835 -0.09033822  0.1467143
#   -0.29725705  0.21033524 -0.33160909  0.0411235  -0.35016763 -0.07050802]
#  [ 0.21414764  0.2035185   0.05387088  0.1800149   0.23539577  0.34040105
#   -0.09731708  0.27365795 -0.05727544  0.26727882 -0.01996423  0.14469742]
#  [ 0.23801892  0.21358101 -0.23951358  0.19012759 -0.2081782   0.11830056
#   -0.24753273  0.0995945  -0.29421195  0.10356572 -0.28969212  0.14318778]]

# %% [markdown]
# ## VLAD
# - This is the method to replace the previouse bag of feature, that instead do the counting of each of word, here we are calculate the residuals (differences between descriptors and the cluster center)

# %%
import vlad

trainX_centerSubstract, trainy_centerSubstract = vlad.my_vlad(centroids, X_train_classifier, y_train_classifier)
testX_centerSubstract, testy_centerSubstract = vlad.my_vlad(centroids, X_test, y_test)
# Out:
# vlad before X.shape (12, 10)
# vlad after X.shape (12, 10, 12, 129)
# After transpose Xt.shape (12, 10, 129, 12)
# vlad before X.shape (2, 10)
# vlad after X.shape (2, 10, 12, 129)
# After transpose Xt.shape (2, 10, 129, 12)

# %% [markdown]
# ## Train classifier
# - Here I use KNeighborsClassifier with grid search for finding the best parameter
# - We should never use the data twice, and therefore here I used the second split from X_train for training purpose

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
param_grid = {'n_neighbors': np.arange(3, 10),'weights':('uniform', 'distance'), 'algorithm':('auto','ball_tree', 'kd_tree', 'brute') }
np.set_printoptions(suppress=True)
grid_search = GridSearchCV(KNeighborsClassifier(), param_grid, verbose=3)
grid_search.fit(trainX_centerSubstract, trainy_centerSubstract)
print "----------------", "Done grid search", "----------------"
# Out:
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# [CV] n_neighbors=3, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=3, weights=uniform, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=3, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=3, weights=uniform, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=3, weights=distance, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=4, weights=uniform, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=4, weights=uniform, algorithm=auto, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=4, weights=uniform, algorithm=auto, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=4, weights=distance, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=4, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=4, weights=distance, algorithm=auto, score=0.975000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=5, weights=uniform, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=5, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=5, weights=uniform, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=5, weights=distance, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=5, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=5, weights=distance, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=6, weights=uniform, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=6, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=6, weights=uniform, algorithm=auto, score=0.975000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=6, weights=distance, algorithm=auto, score=0.750000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=6, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=6, weights=distance, algorithm=auto, score=0.975000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=7, weights=uniform, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=7, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=7, weights=uniform, algorithm=auto, score=0.925000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=7, weights=distance, algorithm=auto, score=0.925000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=8, weights=uniform, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=8, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=8, weights=uniform, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=8, weights=distance, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=8, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=8, weights=distance, algorithm=auto, score=0.950000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=9, weights=uniform, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=9, weights=uniform, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=auto ..................
# [CV]  n_neighbors=9, weights=uniform, algorithm=auto, score=0.900000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=auto .................
# [CV]  n_neighbors=9, weights=distance, algorithm=auto, score=0.900000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=3, weights=uniform, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=3, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=3, weights=uniform, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=3, weights=distance, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=4, weights=uniform, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=4, weights=uniform, algorithm=ball_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=4, weights=uniform, algorithm=ball_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=4, weights=distance, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=4, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=4, weights=distance, algorithm=ball_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=5, weights=uniform, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=5, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=5, weights=uniform, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=5, weights=distance, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=6, weights=uniform, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=6, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=6, weights=uniform, algorithm=ball_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=6, weights=distance, algorithm=ball_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=6, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=6, weights=distance, algorithm=ball_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=7, weights=uniform, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=7, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=7, weights=uniform, algorithm=ball_tree, score=0.925000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=7, weights=distance, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=7, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=7, weights=distance, algorithm=ball_tree, score=0.925000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=8, weights=uniform, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=8, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=8, weights=uniform, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=8, weights=distance, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=8, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=8, weights=distance, algorithm=ball_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=9, weights=uniform, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=9, weights=uniform, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=ball_tree .............
# [CV]  n_neighbors=9, weights=uniform, algorithm=ball_tree, score=0.900000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=9, weights=distance, algorithm=ball_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=9, weights=distance, algorithm=ball_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=ball_tree ............
# [CV]  n_neighbors=9, weights=distance, algorithm=ball_tree, score=0.900000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=3, weights=uniform, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=3, weights=distance, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=3, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=3, weights=distance, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=4, weights=uniform, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=4, weights=uniform, algorithm=kd_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=4, weights=uniform, algorithm=kd_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=4, weights=distance, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=4, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=4, weights=distance, algorithm=kd_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=5, weights=uniform, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=5, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=5, weights=uniform, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=5, weights=distance, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=5, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=5, weights=distance, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=6, weights=uniform, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=6, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=6, weights=uniform, algorithm=kd_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=6, weights=distance, algorithm=kd_tree, score=0.750000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=6, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=6, weights=distance, algorithm=kd_tree, score=0.975000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=7, weights=uniform, algorithm=kd_tree, score=0.925000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=7, weights=distance, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=7, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=7, weights=distance, algorithm=kd_tree, score=0.925000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=8, weights=uniform, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=8, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=8, weights=uniform, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=kd_tree ..............
# [Parallel(n_jobs=1)]: Done  31 tasks       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 127 tasks       | elapsed:    0.4s
# [CV]  n_neighbors=8, weights=distance, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=8, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=8, weights=distance, algorithm=kd_tree, score=0.950000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=9, weights=uniform, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=9, weights=uniform, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=kd_tree ...............
# [CV]  n_neighbors=9, weights=uniform, algorithm=kd_tree, score=0.900000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=9, weights=distance, algorithm=kd_tree, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=9, weights=distance, algorithm=kd_tree, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=kd_tree ..............
# [CV]  n_neighbors=9, weights=distance, algorithm=kd_tree, score=0.900000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=3, weights=uniform, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=3, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=3, weights=uniform, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=3, weights=distance, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=3, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=3, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=3, weights=distance, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=4, weights=uniform, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=4, weights=uniform, algorithm=brute, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=4, weights=uniform, algorithm=brute, score=0.975000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=4, weights=distance, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=4, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=4, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=4, weights=distance, algorithm=brute, score=0.975000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=5, weights=uniform, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=5, weights=distance, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=5, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=5, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=5, weights=distance, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=6, weights=uniform, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=6, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=6, weights=uniform, algorithm=brute, score=0.975000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=6, weights=distance, algorithm=brute, score=0.750000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=6, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=6, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=6, weights=distance, algorithm=brute, score=0.975000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=7, weights=uniform, algorithm=brute, score=0.925000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=7, weights=distance, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=7, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=7, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=7, weights=distance, algorithm=brute, score=0.925000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=8, weights=uniform, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=8, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=8, weights=uniform, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=8, weights=distance, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=8, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=8, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=8, weights=distance, algorithm=brute, score=0.950000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=9, weights=uniform, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=9, weights=uniform, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=uniform, algorithm=brute .................
# [CV]  n_neighbors=9, weights=uniform, algorithm=brute, score=0.900000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=9, weights=distance, algorithm=brute, score=0.775000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=9, weights=distance, algorithm=brute, score=1.000000 -   0.0s
# [CV] n_neighbors=9, weights=distance, algorithm=brute ................
# [CV]  n_neighbors=9, weights=distance, algorithm=brute, score=0.900000 -   0.0s
# ---------------- Done grid search ----------------
# [Parallel(n_jobs=1)]: Done 168 out of 168 | elapsed:    0.5s finished

# %% [markdown]
# ## Predict
# - Use the previous splitted test data for prediction
# - I got 100% prediction. Before I was using the same training set for both center and classifier purpose, and only got 85% prediction. So never use the data again will yeild significant improvement

# %%
predict = grid_search.predict(testX_centerSubstract)
print grid_search.score(testX_centerSubstract, testy_centerSubstract)
print grid_search.best_params_
# Out:
# 1.0
# {'n_neighbors': 6, 'weights': 'uniform', 'algorithm': 'auto'}
